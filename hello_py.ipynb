# %% [markdown]
# <a href="https://colab.research.google.com/github/shermuel/python/blob/main/hello_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# shermuel kenward

name = input("what's your name ")
age = input("how old are you ")

print("hello,"+name+"!")
print("you are "+age+" years old.")
# Out:
# what's your name shermuel
# how old are you 21
# hello,shermuel!
# you are 21 years old.
